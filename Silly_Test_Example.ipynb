# %%
import os
from collections import defaultdict
import logging
logging.getLogger().setLevel(logging.INFO)
logging.basicConfig(format='%(message)s')
import pickle

import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import polyga.analysis as pga
from polyga import polygod as pg
from polyga import utils
from polyga.selection_schemes import elite

#This is specifically for polymers
from rdkit import Chem, RDLogger
RDLogger.DisableLog('rdApp.*')
from rdkit.Chem import AllChem, DataStructs
# Out:
# Enabling RDKit 2021.09.2 jupyter extensions

# %% [markdown]
# # Feature generation
# Here, I am creating a simple fingerprinting scheme for my polymers.
# This is not what I would use in real life.

# %%
def silly_fingerprint(df):                                                         
    """Morgan fingerprint with count of chars in smiles_string.                    
                                                                                   
    I wouldn't use this for actual research.                                       
                                                                                   
    Args:                                                                          
        df (pd.DataFrame):                                                         
            dataframe of polyga population                                         
                                                                                   
    Returns:                                                                       
        same dataframe with fingerprints attached                                  
    """                                                                            
    fp_dict = defaultdict(list)                                                    
    columns = df.columns                                                           
    for index, row in df.iterrows():                                               
        try:                                                                       
            smiles = row['smiles_string']                                          
            # These are used for ladder polymers, so we have to remove them        
            # or we get a parsing error                                            
            smiles = smiles.replace('e','*').replace('t','*').replace('d','*').replace('g','*')
            m = Chem.MolFromSmiles(smiles)                                         
            # Make radius 5 so we have unique fingerprints                         
            fp = AllChem.GetMorganFingerprintAsBitVect(m, 5, nBits=2048)           
            arr = np.zeros((0,), dtype=np.int8)                                    
            DataStructs.ConvertToNumpyArray(fp,arr)                                
            # Add fake fingerprint to differentiate repeats                        
            fp_dict['fp_' + 'num_str_atoms'].append(len(smiles))                   
            for i in range(len(arr)):                                              
                fp_dict['fp_' + str(i)].append(arr[i])                             
            for col in columns:                                                    
                fp_dict[col].append(row[col])                                      
        except Exception as e:                                                     
            # Skip failed fingerprinting                                           
            continue                                                               
                                                                                   
    fp_df = pd.DataFrame.from_dict(fp_dict)                                        
    keys = [key for key in fp_dict.keys()]                                         
    for key in keys:                                                               
        del fp_dict[key]                                                           
    del keys                                                                       
    del fp_dict                                                                    
                                                                                   
    fp_headers = [col for col in fp_df.columns if 'fp_' in col]                    
    return fp_df, fp_headers

# %% [markdown]
# # Property prediction
# Here, I am predicting the properties of my polymers. Note how I have passed a dataframe, list of headers
# and a dictionary with a key for the parameter name and value of the model. All property predictors function must take these
# inputs, even if models is None.

# %%
def silly_property_prediction(df, fp_headers, models):                          
    """Predict silly properties of polymers                                     
                                                                                
    Args:                                                                       
        df (pd.DataFrame):                                                      
            dataframe of fingerprinted polymers                                 
        fp_headers (list):                                                      
            list of fingerprint headers                                         
        models (dict):                                                          
            Key is parameter name, value is the model                           
                                                                                
    Returns:                                                                    
        same dataframe with predictions attached                                
    """                                                                         
    prop_values = defaultdict(list)                                             
    for model in models:                                                        
        prop_values[model] = (                                                  
                models[model].predict(df[fp_headers].values).reshape(-1)        
                )                                                               
                                                                                
    keys = [key for key in prop_values.keys()]                                  
    for key in keys:                                                            
        df[key] = prop_values[key].copy()                                       
        del prop_values[key]                                                    
    del keys                                                                    
    del prop_values                                                             
                                                                                
    return df

# %% [markdown]
# # Fitness function
# Now, I am defining the fitness function. I know the property names will match the keys of the dictionary from the property predictor above, and I know those because I define them below. I use a MinMaxScaler to scale all values between 0 and 1, and then do a simple linear combination of properties to assess the fitness of each one.

# %%
def make_coolest_funniest_smartest_polymer(df, fp_headers):                     
    """Make the coolest fricken polymer around                                  
                                                                                
    Args:                                                                       
        df (pd.DataFrame):                                                      
            dataframe of population with properties predicted                   
                                                                                
    Returns:                                                                    
        Same dataframe with fitness function attached                           
    """                                                                         
    # Same names as returned property                                           
    properties = [                                                              
                  'Polymer_Coolness',                                           
                  'Polymer_Intelligence',                                       
                  'Polymer_Funnyness'                                           
                  ]                                                             
                                                                                
    fitness = []                                                                
    scaled_dict = {}                                                            
    for prop in properties:                                                     
        vals = np.array(df[prop].values)                                        
        vals = np.reshape(vals, (len(vals), -1))                                
        scaler = MinMaxScaler()                                                 
        scaled_vals = scaler.fit_transform(vals)                                
        scaled_dict[prop] = scaled_vals                                         
                                                                                
    for i in range(len(df)):                                                    
        fit = 0                                                                 
        for prop in properties:                                                 
            fit += 1/3 * scaled_dict[prop][i][0]                                
        fitness.append(fit)                                                     
                                                                                
    df['fitness'] = fitness                                                     
    return df

# %% [markdown]
# # Loading models
# This is where I have loaded the models and set what the property names will be for the above function.

# %%
# Load models for property predictions                                             
model_folder = 'bin'                                                          
properties = {                                                                     
          'Polymer_Coolness': 'Polymer_Coolness_random-forest.pkl',                
          'Polymer_Intelligence': 'Polymer_Intelligence_random-forest.pkl',        
          'Polymer_Funnyness': 'Polymer_Funnyness_random-forest.pkl'               
         }                                                                         
models = {}

for prop in properties:                                                            
    model_file = open(os.path.join(model_folder, properties[prop]), 'rb')          
    models[prop] = pickle.load(model_file)                                         
    model_file.close()
# Out:
# /Users/josephkern/Desktop/GA/polyga_example/src/.venv/lib/python3.7/site-packages/sklearn/base.py:315: UserWarning: Trying to unpickle estimator DecisionTreeRegressor from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /Users/josephkern/Desktop/GA/polyga_example/src/.venv/lib/python3.7/site-packages/sklearn/base.py:315: UserWarning: Trying to unpickle estimator RandomForestRegressor from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %% [markdown]
# # Creating the planet
# The basic data I need to create the planet is a name for it (which will also be the name for a savefolder containing it), the predict_function that will generate the property predictions, the fingerprint function that will create the features for our materials, and the models for property prediction. I could also choose to not pass the models and instead load them each time in the function instead, but that might be slower.

# %%
planet = pg.PolyPlanet('Planet_Silly',                                             
        predict_function=silly_property_prediction,                    
        fingerprint_function=silly_fingerprint,                        
        models=models, save_folder='data'                                                              
        )

# %% [markdown]
# # Creating a land
# On the land, I define the generative function (function used to combine dna), and the fitness function. I can create multiple lands, each with different functions if I choose. More alterable variable are available in the docs on github.

# %%
land = pg.PolyLand('Awesomeland', planet,                                          
        generative_function=utils.chromosome_ids_to_smiles,                        
        fitness_function=make_coolest_funniest_smartest_polymer        
        )

# %% [markdown]
# # Creating a nation
# Now I can create a nation. I have to choose the selection scheme, partner selection scheme, and the number of initial population. The details for these can be read in the docs. In this case, I want to choose the highest scoring polymers from each generation, have them mate with the polymers least like them according to their tanimoto similarity score, and start with a population of 180.

# %%
nation = pg.PolyNation('UnitedPolymersOfCool', land,                               
                       selection_scheme=elite,                   
                       partner_selection='diversity',                              
                       num_population_initial=180,                                 
                       )

# %% [markdown]
# # Running
# Now we run the code!

# %%
for i in range(10):
    planet.advance_time()
# Out:
# Age of planet Planet_Silly: 0
# The polymers of UnitedPolymersOfCool took 0.6184 years to mature.
# The polymers of UnitedPolymersOfCool took 0.0504 years to graduate college.
# The polymers of UnitedPolymersOfCool worked for 0.0021 years.
# No other nations exist for the polymers of UnitedPolymersOfCool to immigrate to
# Age of land Awesomeland is 0
# UnitedPolymersOfCool of Awesomeland advances through time
# The polymers of UnitedPolymersOfCool worked for 0.0028 polyears.
# The polymers of UnitedPolymersOfCool married!
# The nation of UnitedPolymersOfCool took 0.644 years to finish their census!
# There are 151 polymers in the nation
# After 0.0383 years they had children.
# Generation 0 of UnitedPolymersOfCool have all passed away
# Age of planet Planet_Silly: 1
# The polymers of UnitedPolymersOfCool took 0.5737 years to mature.
# The polymers of UnitedPolymersOfCool took 0.0712 years to graduate college.
# The polymers of UnitedPolymersOfCool worked for 0.0018 years.
# No other nations exist for the polymers of UnitedPolymersOfCool to immigrate to
# Age of land Awesomeland is 1
# UnitedPolymersOfCool of Awesomeland advances through time
# The polymers of UnitedPolymersOfCool worked for 0.0036 polyears.
# The polymers of UnitedPolymersOfCool married!
# The nation of UnitedPolymersOfCool took 0.7124 years to finish their census!
# There are 163 polymers in the nation
# After 0.0308 years they had children.
# Generation 1 of UnitedPolymersOfCool have all passed away
# Age of planet Planet_Silly: 2
# The polymers of UnitedPolymersOfCool took 0.5806 years to mature.
# The polymers of UnitedPolymersOfCool took 0.0469 years to graduate college.
# The polymers of UnitedPolymersOfCool worked for 0.0018 years.
# No other nations exist for the polymers of UnitedPolymersOfCool to immigrate to
# Age of land Awesomeland is 2
# UnitedPolymersOfCool of Awesomeland advances through time
# The polymers of UnitedPolymersOfCool worked for 0.0028 polyears.
# The polymers of UnitedPolymersOfCool married!
# The nation of UnitedPolymersOfCool took 0.6192 years to finish their census!
# There are 154 polymers in the nation
# After 0.0306 years they had children.
# Generation 2 of UnitedPolymersOfCool have all passed away
# Age of planet Planet_Silly: 3
# The polymers of UnitedPolymersOfCool took 0.5688 years to mature.
# The polymers of UnitedPolymersOfCool took 0.0472 years to graduate college.
# The polymers of UnitedPolymersOfCool worked for 0.0055 years.
# No other nations exist for the polymers of UnitedPolymersOfCool to immigrate to
# Age of land Awesomeland is 3
# UnitedPolymersOfCool of Awesomeland advances through time
# The polymers of UnitedPolymersOfCool worked for 0.0055 polyears.
# The polymers of UnitedPolymersOfCool married!
# The nation of UnitedPolymersOfCool took 0.7682 years to finish their census!
# There are 154 polymers in the nation
# After 0.0677 years they had children.
# Generation 3 of UnitedPolymersOfCool have all passed away
# Age of planet Planet_Silly: 4
# The polymers of UnitedPolymersOfCool took 0.9834 years to mature.
# The polymers of UnitedPolymersOfCool took 0.0493 years to graduate college.
# The polymers of UnitedPolymersOfCool worked for 0.0022 years.
# No other nations exist for the polymers of UnitedPolymersOfCool to immigrate to
# Age of land Awesomeland is 4
# UnitedPolymersOfCool of Awesomeland advances through time
# The polymers of UnitedPolymersOfCool worked for 0.0029 polyears.
# The polymers of UnitedPolymersOfCool married!
# The nation of UnitedPolymersOfCool took 0.8071 years to finish their census!
# There are 159 polymers in the nation
# After 0.0348 years they had children.
# Generation 4 of UnitedPolymersOfCool have all passed away
# Age of planet Planet_Silly: 5
# The polymers of UnitedPolymersOfCool took 0.6044 years to mature.
# The polymers of UnitedPolymersOfCool took 0.0461 years to graduate college.
# The polymers of UnitedPolymersOfCool worked for 0.0019 years.
# No other nations exist for the polymers of UnitedPolymersOfCool to immigrate to
# Age of land Awesomeland is 5
# UnitedPolymersOfCool of Awesomeland advances through time
# The polymers of UnitedPolymersOfCool worked for 0.0032 polyears.
# The polymers of UnitedPolymersOfCool married!
# The nation of UnitedPolymersOfCool took 0.6279 years to finish their census!
# There are 155 polymers in the nation
# After 0.0332 years they had children.
# Generation 5 of UnitedPolymersOfCool have all passed away
# Age of planet Planet_Silly: 6
# The polymers of UnitedPolymersOfCool took 0.7139 years to mature.
# The polymers of UnitedPolymersOfCool took 0.0498 years to graduate college.
# The polymers of UnitedPolymersOfCool worked for 0.0057 years.
# No other nations exist for the polymers of UnitedPolymersOfCool to immigrate to
# Age of land Awesomeland is 6
# UnitedPolymersOfCool of Awesomeland advances through time
# The polymers of UnitedPolymersOfCool worked for 0.0029 polyears.
# The polymers of UnitedPolymersOfCool married!
# The nation of UnitedPolymersOfCool took 0.7104 years to finish their census!
# There are 158 polymers in the nation
# After 0.0522 years they had children.
# Generation 6 of UnitedPolymersOfCool have all passed away
# Age of planet Planet_Silly: 7
# The polymers of UnitedPolymersOfCool took 0.6635 years to mature.
# The polymers of UnitedPolymersOfCool took 0.0485 years to graduate college.
# The polymers of UnitedPolymersOfCool worked for 0.0018 years.
# No other nations exist for the polymers of UnitedPolymersOfCool to immigrate to
# Age of land Awesomeland is 7
# UnitedPolymersOfCool of Awesomeland advances through time
# The polymers of UnitedPolymersOfCool worked for 0.0042 polyears.
# The polymers of UnitedPolymersOfCool married!
# The nation of UnitedPolymersOfCool took 0.7463 years to finish their census!
# There are 157 polymers in the nation
# After 0.027 years they had children.
# Generation 7 of UnitedPolymersOfCool have all passed away
# Age of planet Planet_Silly: 8
# The polymers of UnitedPolymersOfCool took 0.7356 years to mature.
# The polymers of UnitedPolymersOfCool took 0.0704 years to graduate college.
# The polymers of UnitedPolymersOfCool worked for 0.0042 years.
# No other nations exist for the polymers of UnitedPolymersOfCool to immigrate to
# Age of land Awesomeland is 8
# UnitedPolymersOfCool of Awesomeland advances through time
# The polymers of UnitedPolymersOfCool worked for 0.0057 polyears.
# The polymers of UnitedPolymersOfCool married!
# The nation of UnitedPolymersOfCool took 0.6723 years to finish their census!
# There are 154 polymers in the nation
# After 0.0266 years they had children.
# Generation 8 of UnitedPolymersOfCool have all passed away
# Age of planet Planet_Silly: 9
# The polymers of UnitedPolymersOfCool took 1.0086 years to mature.
# The polymers of UnitedPolymersOfCool took 0.0617 years to graduate college.
# The polymers of UnitedPolymersOfCool worked for 0.0027 years.
# No other nations exist for the polymers of UnitedPolymersOfCool to immigrate to
# Age of land Awesomeland is 9
# UnitedPolymersOfCool of Awesomeland advances through time
# The polymers of UnitedPolymersOfCool worked for 0.0027 polyears.
# The polymers of UnitedPolymersOfCool married!
# The nation of UnitedPolymersOfCool took 0.6515 years to finish their census!
# There are 154 polymers in the nation
# After 0.0291 years they had children.
# Generation 9 of UnitedPolymersOfCool have all passed away

# %% [markdown]
# # Analysis
# Next, we'll create some functions to analyze the results.

# %%
def plot_average_lengths(df):
    """Plots average lengths of polymers vs generation for all settled_nations"""
    gens = max(df.generation) + 1
    x = np.linspace(0, gens, gens)
    settled_nations = np.unique(df.settled_nation.values)
    legend = []
    for settled_nation in settled_nations:
        tdf = df.loc[df['settled_nation'] == settled_nation]
        means = []
        for gen in range(gens):
            tdf_ = tdf.loc[tdf['generation'] == gen]
            mean = tdf_.num_chromosomes.mean()
            means.append(mean)
        plt.plot(x, means)
        legend.append(settled_nation)
    plt.legend(legend)
    plt.show()

# %%
def plot_property_averages(df):
    """Plots property averages for all settled_nations and displays them separately."""
    properties = ['Polymer_Coolness', 'Polymer_Funnyness','Polymer_Intelligence']
    goals = [200, 200, 200]
    dirs = [1, 1, 1]
    settled_nations = np.unique(df.settled_nation.values)
    for settled_nation in settled_nations:
        vals = []
        tdf = df.loc[df.settled_nation == settled_nation]
        for prop in properties:
            val = []
            for i in range(max(tdf.generation) + 1):
                tdf_ = tdf.loc[tdf['generation'] == i]
                val.append(tdf_[prop].mean())
            vals.append(val)

        fig, axes = plt.subplots(nrows=1, ncols=3, figsize=[16,9])
        x = np.linspace(0, max(tdf.generation), max(tdf.generation)+1)
        x = [val + 1 for val in x]
        row = 0
        col = 0
        curr = 0
        for prop in properties:
            upper_line = [max(vals[curr])]*len(x)
            lower_line = [min(vals[curr])]*len(x)
            axes[col].plot(x, vals[curr], lw=2, c='darkred', zorder=4)
            axes[col].set_ylabel(prop)
            axes[col].set_ylim([min(min(vals[curr]), goals[curr]),
                                     max(max(vals[curr]), goals[curr])])
            axes[col].set_xlim([1,max(tdf.generation)+1])
            axes[col].set_xscale("log")
            goal_line = [goals[curr]]*len(x)
            if (dirs[curr] == 1 and max(vals[curr]) > goals[curr]):
                axes[col].fill_between(x,goal_line,upper_line,zorder=3,alpha=.5,
                                 facecolor='gray')
            elif (dirs[curr] == -1 and min(vals[curr]) < goals[curr]):
                axes[col].fill_between(x,lower_line,goal_line,zorder=3,alpha=.5,
                                 facecolor='gray')
            curr += 1
            col += 1
            if col > 3:
                col = 0
                row += 1
        fig.suptitle(settled_nation)
        plt.show()

# %%
def count_num_successful_pols(df):
    """Counts all polymers achieving targets"""
    properties = ['Polymer_Coolness', 'Polymer_Funnyness','Polymer_Intelligence']
    goals = [200, 200, 200]
    dirs = [1, 1, 1]
    settled_nations = np.unique(df.settled_nation.values)
    for settled_nation in settled_nations:
        tdf = df.loc[df.settled_nation == settled_nation]
        num_pols = len(tdf)
        for i in range(len(goals)):
            goal = goals[i]
            dir_ = dirs[i]
            prop = properties[i]
            if dir_ == 1:
                tdf = tdf.loc[tdf[prop] >= goal]
            else: 
                tdf = tdf.loc[tdf[prop] <= goal]
        print("{}: {} / {}".format(settled_nation, len(tdf), num_pols))

# %% [markdown]
# # Loading
# Here is a nice helper function to load the data. You just have to pass the

# %%
df, fp_df = pga.load_planet('data/Planet_Silly')

# %%
plot_property_averages(df)

# %%
plot_average_lengths(df)

# %%
count_num_successful_pols(df)
# Out:
# UnitedPolymersOfCool: 0 / 1559

# %% [markdown]
# # Running again
# We haven't met our goal for intelligence, so let's run a little longer.

# %%
for i in range(10):
    planet.advance_time()
# Out:
# Age of planet Planet_Silly: 10
# The polymers of UnitedPolymersOfCool took 0.9038 years to mature.
# The polymers of UnitedPolymersOfCool took 0.048 years to graduate college.
# The polymers of UnitedPolymersOfCool worked for 0.0034 years.
# No other nations exist for the polymers of UnitedPolymersOfCool to immigrate to
# Age of land Awesomeland is 10
# UnitedPolymersOfCool of Awesomeland advances through time
# The polymers of UnitedPolymersOfCool worked for 0.0031 polyears.
# The polymers of UnitedPolymersOfCool married!
# The nation of UnitedPolymersOfCool took 0.8687 years to finish their census!
# There are 152 polymers in the nation
# After 0.0507 years they had children.
# Generation 10 of UnitedPolymersOfCool have all passed away
# Age of planet Planet_Silly: 11
# The polymers of UnitedPolymersOfCool took 0.7976 years to mature.
# The polymers of UnitedPolymersOfCool took 0.0439 years to graduate college.
# The polymers of UnitedPolymersOfCool worked for 0.0019 years.
# No other nations exist for the polymers of UnitedPolymersOfCool to immigrate to
# Age of land Awesomeland is 11
# UnitedPolymersOfCool of Awesomeland advances through time
# The polymers of UnitedPolymersOfCool worked for 0.0033 polyears.
# The polymers of UnitedPolymersOfCool married!
# The nation of UnitedPolymersOfCool took 0.6611 years to finish their census!
# There are 164 polymers in the nation
# After 0.0334 years they had children.
# Generation 11 of UnitedPolymersOfCool have all passed away
# Age of planet Planet_Silly: 12
# The polymers of UnitedPolymersOfCool took 0.8323 years to mature.
# The polymers of UnitedPolymersOfCool took 0.0461 years to graduate college.
# The polymers of UnitedPolymersOfCool worked for 0.0019 years.
# No other nations exist for the polymers of UnitedPolymersOfCool to immigrate to
# Age of land Awesomeland is 12
# UnitedPolymersOfCool of Awesomeland advances through time
# The polymers of UnitedPolymersOfCool worked for 0.0038 polyears.
# The polymers of UnitedPolymersOfCool married!
# The nation of UnitedPolymersOfCool took 0.6542 years to finish their census!
# There are 160 polymers in the nation
# After 0.0335 years they had children.
# Generation 12 of UnitedPolymersOfCool have all passed away
# Age of planet Planet_Silly: 13
# The polymers of UnitedPolymersOfCool took 0.8518 years to mature.
# The polymers of UnitedPolymersOfCool took 0.0515 years to graduate college.
# The polymers of UnitedPolymersOfCool worked for 0.0019 years.
# No other nations exist for the polymers of UnitedPolymersOfCool to immigrate to
# Age of land Awesomeland is 13
# UnitedPolymersOfCool of Awesomeland advances through time
# The polymers of UnitedPolymersOfCool worked for 0.003 polyears.
# The polymers of UnitedPolymersOfCool married!
# The nation of UnitedPolymersOfCool took 0.7871 years to finish their census!
# There are 148 polymers in the nation
# After 0.0346 years they had children.
# Generation 13 of UnitedPolymersOfCool have all passed away
# Age of planet Planet_Silly: 14
# The polymers of UnitedPolymersOfCool took 0.9527 years to mature.
# The polymers of UnitedPolymersOfCool took 0.0542 years to graduate college.
# The polymers of UnitedPolymersOfCool worked for 0.0018 years.
# No other nations exist for the polymers of UnitedPolymersOfCool to immigrate to
# Age of land Awesomeland is 14
# UnitedPolymersOfCool of Awesomeland advances through time
# The polymers of UnitedPolymersOfCool worked for 0.003 polyears.
# The polymers of UnitedPolymersOfCool married!
# The nation of UnitedPolymersOfCool took 0.6938 years to finish their census!
# There are 153 polymers in the nation
# After 0.0642 years they had children.
# Generation 14 of UnitedPolymersOfCool have all passed away
# Age of planet Planet_Silly: 15
# The polymers of UnitedPolymersOfCool took 0.979 years to mature.
# The polymers of UnitedPolymersOfCool took 0.0571 years to graduate college.
# The polymers of UnitedPolymersOfCool worked for 0.0021 years.
# No other nations exist for the polymers of UnitedPolymersOfCool to immigrate to
# Age of land Awesomeland is 15
# UnitedPolymersOfCool of Awesomeland advances through time
# The polymers of UnitedPolymersOfCool worked for 0.0038 polyears.
# The polymers of UnitedPolymersOfCool married!
# The nation of UnitedPolymersOfCool took 0.6552 years to finish their census!
# There are 152 polymers in the nation
# After 0.0545 years they had children.
# Generation 15 of UnitedPolymersOfCool have all passed away
# Age of planet Planet_Silly: 16
# The polymers of UnitedPolymersOfCool took 0.9459 years to mature.
# The polymers of UnitedPolymersOfCool took 0.0538 years to graduate college.
# The polymers of UnitedPolymersOfCool worked for 0.0039 years.
# No other nations exist for the polymers of UnitedPolymersOfCool to immigrate to
# Age of land Awesomeland is 16
# UnitedPolymersOfCool of Awesomeland advances through time
# The polymers of UnitedPolymersOfCool worked for 0.0029 polyears.
# The polymers of UnitedPolymersOfCool married!
# The nation of UnitedPolymersOfCool took 0.8322 years to finish their census!
# There are 151 polymers in the nation
# After 0.0364 years they had children.
# Generation 16 of UnitedPolymersOfCool have all passed away
# Age of planet Planet_Silly: 17
# The polymers of UnitedPolymersOfCool took 0.826 years to mature.
# The polymers of UnitedPolymersOfCool took 0.047 years to graduate college.
# The polymers of UnitedPolymersOfCool worked for 0.0018 years.
# No other nations exist for the polymers of UnitedPolymersOfCool to immigrate to
# Age of land Awesomeland is 17
# UnitedPolymersOfCool of Awesomeland advances through time
# The polymers of UnitedPolymersOfCool worked for 0.0034 polyears.
# The polymers of UnitedPolymersOfCool married!
# The nation of UnitedPolymersOfCool took 0.7563 years to finish their census!
# There are 156 polymers in the nation
# After 0.0446 years they had children.
# Generation 17 of UnitedPolymersOfCool have all passed away
# Age of planet Planet_Silly: 18
# The polymers of UnitedPolymersOfCool took 0.8161 years to mature.
# The polymers of UnitedPolymersOfCool took 0.0477 years to graduate college.
# The polymers of UnitedPolymersOfCool worked for 0.0031 years.
# No other nations exist for the polymers of UnitedPolymersOfCool to immigrate to
# Age of land Awesomeland is 18
# UnitedPolymersOfCool of Awesomeland advances through time
# The polymers of UnitedPolymersOfCool worked for 0.0036 polyears.
# The polymers of UnitedPolymersOfCool married!
# The nation of UnitedPolymersOfCool took 0.7466 years to finish their census!
# There are 151 polymers in the nation
# After 0.0329 years they had children.
# Generation 18 of UnitedPolymersOfCool have all passed away
# Age of planet Planet_Silly: 19
# The polymers of UnitedPolymersOfCool took 0.8112 years to mature.
# The polymers of UnitedPolymersOfCool took 0.0516 years to graduate college.
# The polymers of UnitedPolymersOfCool worked for 0.0021 years.
# No other nations exist for the polymers of UnitedPolymersOfCool to immigrate to
# Age of land Awesomeland is 19
# UnitedPolymersOfCool of Awesomeland advances through time
# The polymers of UnitedPolymersOfCool worked for 0.0029 polyears.
# The polymers of UnitedPolymersOfCool married!
# The nation of UnitedPolymersOfCool took 0.6281 years to finish their census!
# There are 153 polymers in the nation
# After 0.0291 years they had children.
# Generation 19 of UnitedPolymersOfCool have all passed away

# %%
df, fp_df = pga.load_planet('data/Planet_Silly')
plot_property_averages(df)

# %% [markdown]
# # Creating a new land
# We aren't able to get intelligence any higher, so let's try creating a new land just dedicated to increasing that. We'll define a fitness function, then create the new land and nation. Then we'll tell some of these polymers to imigrate to the UnitedPolymersOfCool.

# %%
def make_smartest_polymer(df, fp_headers):                     
    """Make the coolest fricken polymer around                                  
                                                                                
    Args:                                                                       
        df (pd.DataFrame):                                                      
            dataframe of population with properties predicted                   
                                                                                
    Returns:                                                                    
        Same dataframe with fitness function attached                           
    """                                                                         
    # Same names as returned property                                           
    properties = [                                                                                                       
                  'Polymer_Intelligence',                                                                                 
                  ]                                                             
                                                                                
    fitness = []                                                                
    scaled_dict = {}                                                            
    for prop in properties:                                                     
        vals = np.array(df[prop].values)                                        
        vals = np.reshape(vals, (len(vals), -1))                                
        scaler = MinMaxScaler()                                                 
        scaled_vals = scaler.fit_transform(vals)                                
        scaled_dict[prop] = scaled_vals                                         
                                                                                
    for i in range(len(df)):                                                    
        fit = 0                                                                 
        for prop in properties:                                                 
            fit += 1*scaled_dict[prop][i][0]                                
        fitness.append(fit)                                                     
                                                                                
    df['fitness'] = fitness                                                     
    return df

# %%
land2 = pg.PolyLand('SmartLand', planet, 
                   generative_function=utils.chromosome_ids_to_smiles,
                   fitness_function=make_smartest_polymer
)
nation2 = pg.PolyNation('Eureka', land2, selection_scheme=elite, 
                       partner_selection='diversity', num_population_initial=100,
                       emigration_rate=0.02, emigration_selection='best_worst',
)

# %%
for i in range(10):
    planet.advance_time()
# Out:
# Age of planet Planet_Silly: 20
# The polymers of UnitedPolymersOfCool took 0.8638 years to mature.
# The polymers of UnitedPolymersOfCool took 0.0503 years to graduate college.
# The polymers of UnitedPolymersOfCool worked for 0.0028 years.
# The polymers of UnitedPolymersOfCool emigrated over 0.6383 years.
# The polymers of Eureka took 0.3421 years to mature.
# The polymers of Eureka took 0.0427 years to graduate college.
# The polymers of Eureka worked for 0.0012 years.
# The polymers of Eureka emigrated over 0.5734 years.
# Age of land Awesomeland is 20
# UnitedPolymersOfCool of Awesomeland advances through time
# The polymers of UnitedPolymersOfCool worked for 0.0047 polyears.
# The polymers of UnitedPolymersOfCool married!
# The nation of UnitedPolymersOfCool took 0.6847 years to finish their census!
# There are 135 polymers in the nation
# After 0.0351 years they had children.
# Generation 20 of UnitedPolymersOfCool have all passed away
# Age of land SmartLand is 0
# Eureka of SmartLand advances through time
# The polymers of Eureka worked for 0.002 polyears.
# The polymers of Eureka married!
# The nation of Eureka took 0.5777 years to finish their census!
# There are 98 polymers in the nation
# After 0.0793 years they had children.
# Generation 0 of Eureka have all passed away
# Age of planet Planet_Silly: 21
# The polymers of UnitedPolymersOfCool took 0.8564 years to mature.
# The polymers of UnitedPolymersOfCool took 0.0518 years to graduate college.
# The polymers of UnitedPolymersOfCool worked for 0.0022 years.
# The polymers of UnitedPolymersOfCool emigrated over 0.8867 years.
# The polymers of Eureka took 0.6246 years to mature.
# The polymers of Eureka took 0.0449 years to graduate college.
# The polymers of Eureka worked for 0.0016 years.
# The polymers of Eureka emigrated over 0.5847 years.
# Age of land Awesomeland is 21
# UnitedPolymersOfCool of Awesomeland advances through time
# The polymers of UnitedPolymersOfCool worked for 0.0042 polyears.
# The polymers of UnitedPolymersOfCool married!
# The nation of UnitedPolymersOfCool took 0.7096 years to finish their census!
# There are 140 polymers in the nation
# After 0.0331 years they had children.
# Generation 21 of UnitedPolymersOfCool have all passed away
# Age of land SmartLand is 1
# Eureka of SmartLand advances through time
# The polymers of Eureka worked for 0.0045 polyears.
# The polymers of Eureka married!
# The nation of Eureka took 0.9308 years to finish their census!
# There are 180 polymers in the nation
# After 0.0319 years they had children.
# Generation 1 of Eureka have all passed away
# Age of planet Planet_Silly: 22
# The polymers of UnitedPolymersOfCool took 0.9021 years to mature.
# The polymers of UnitedPolymersOfCool took 0.0698 years to graduate college.
# The polymers of UnitedPolymersOfCool worked for 0.0032 years.
# The polymers of UnitedPolymersOfCool emigrated over 0.6651 years.
# The polymers of Eureka took 0.6924 years to mature.
# The polymers of Eureka took 0.0468 years to graduate college.
# The polymers of Eureka worked for 0.0022 years.
# The polymers of Eureka emigrated over 0.577 years.
# Age of land Awesomeland is 22
# UnitedPolymersOfCool of Awesomeland advances through time
# The polymers of UnitedPolymersOfCool worked for 0.0032 polyears.
# The polymers of UnitedPolymersOfCool married!
# The nation of UnitedPolymersOfCool took 0.7912 years to finish their census!
# There are 151 polymers in the nation
# After 0.0342 years they had children.
# Generation 22 of UnitedPolymersOfCool have all passed away
# Age of land SmartLand is 2
# Eureka of SmartLand advances through time
# The polymers of Eureka worked for 0.004 polyears.
# The polymers of Eureka married!
# The nation of Eureka took 0.8188 years to finish their census!
# There are 184 polymers in the nation
# After 0.0315 years they had children.
# Generation 2 of Eureka have all passed away
# Age of planet Planet_Silly: 23
# The polymers of UnitedPolymersOfCool took 0.9206 years to mature.
# The polymers of UnitedPolymersOfCool took 0.0487 years to graduate college.
# The polymers of UnitedPolymersOfCool worked for 0.0021 years.
# The polymers of UnitedPolymersOfCool emigrated over 0.5765 years.
# The polymers of Eureka took 0.7427 years to mature.
# The polymers of Eureka took 0.0465 years to graduate college.
# The polymers of Eureka worked for 0.003 years.
# The polymers of Eureka emigrated over 0.5627 years.
# Age of land Awesomeland is 23
# UnitedPolymersOfCool of Awesomeland advances through time
# The polymers of UnitedPolymersOfCool worked for 0.0029 polyears.
# The polymers of UnitedPolymersOfCool married!
# The nation of UnitedPolymersOfCool took 0.6864 years to finish their census!
# There are 148 polymers in the nation
# After 0.0367 years they had children.
# Generation 23 of UnitedPolymersOfCool have all passed away
# Age of land SmartLand is 3
# Eureka of SmartLand advances through time
# The polymers of Eureka worked for 0.004 polyears.
# The polymers of Eureka married!
# The nation of Eureka took 0.822 years to finish their census!
# There are 184 polymers in the nation
# After 0.0333 years they had children.
# Generation 3 of Eureka have all passed away
# Age of planet Planet_Silly: 24
# The polymers of UnitedPolymersOfCool took 0.9549 years to mature.
# The polymers of UnitedPolymersOfCool took 0.0788 years to graduate college.
# The polymers of UnitedPolymersOfCool worked for 0.0039 years.
# The polymers of UnitedPolymersOfCool emigrated over 0.5984 years.
# The polymers of Eureka took 0.7961 years to mature.
# The polymers of Eureka took 0.0504 years to graduate college.
# The polymers of Eureka worked for 0.0017 years.
# The polymers of Eureka emigrated over 0.5802 years.
# Age of land Awesomeland is 24
# UnitedPolymersOfCool of Awesomeland advances through time
# The polymers of UnitedPolymersOfCool worked for 0.005 polyears.
# The polymers of UnitedPolymersOfCool married!
# The nation of UnitedPolymersOfCool took 0.6984 years to finish their census!
# There are 147 polymers in the nation
# After 0.0503 years they had children.
# Generation 24 of UnitedPolymersOfCool have all passed away
# Age of land SmartLand is 4
# Eureka of SmartLand advances through time
# The polymers of Eureka worked for 0.0034 polyears.
# The polymers of Eureka married!
# The nation of Eureka took 0.9523 years to finish their census!
# There are 179 polymers in the nation
# After 0.0407 years they had children.
# Generation 4 of Eureka have all passed away
# Age of planet Planet_Silly: 25
# The polymers of UnitedPolymersOfCool took 1.1183 years to mature.
# The polymers of UnitedPolymersOfCool took 0.0443 years to graduate college.
# The polymers of UnitedPolymersOfCool worked for 0.0019 years.
# The polymers of UnitedPolymersOfCool emigrated over 0.5896 years.
# The polymers of Eureka took 0.8952 years to mature.
# The polymers of Eureka took 0.0614 years to graduate college.
# The polymers of Eureka worked for 0.0017 years.
# The polymers of Eureka emigrated over 0.641 years.
# Age of land Awesomeland is 25
# UnitedPolymersOfCool of Awesomeland advances through time
# The polymers of UnitedPolymersOfCool worked for 0.0057 polyears.
# The polymers of UnitedPolymersOfCool married!
# The nation of UnitedPolymersOfCool took 0.7364 years to finish their census!
# There are 149 polymers in the nation
# After 0.0271 years they had children.
# Generation 25 of UnitedPolymersOfCool have all passed away
# Age of land SmartLand is 5
# Eureka of SmartLand advances through time
# The polymers of Eureka worked for 0.0057 polyears.
# The polymers of Eureka married!
# The nation of Eureka took 1.0057 years to finish their census!
# There are 182 polymers in the nation
# After 0.0273 years they had children.
# Generation 5 of Eureka have all passed away
# Age of planet Planet_Silly: 26
# The polymers of UnitedPolymersOfCool took 0.8915 years to mature.
# The polymers of UnitedPolymersOfCool took 0.0537 years to graduate college.
# The polymers of UnitedPolymersOfCool worked for 0.0021 years.
# The polymers of UnitedPolymersOfCool emigrated over 0.6396 years.
# The polymers of Eureka took 0.8635 years to mature.
# The polymers of Eureka took 0.0446 years to graduate college.
# The polymers of Eureka worked for 0.0025 years.
# The polymers of Eureka emigrated over 0.571 years.
# Age of land Awesomeland is 26
# UnitedPolymersOfCool of Awesomeland advances through time
# The polymers of UnitedPolymersOfCool worked for 0.0037 polyears.
# The polymers of UnitedPolymersOfCool married!
# The nation of UnitedPolymersOfCool took 1.016 years to finish their census!
# There are 144 polymers in the nation
# After 0.0389 years they had children.
# Generation 26 of UnitedPolymersOfCool have all passed away
# Age of land SmartLand is 6
# Eureka of SmartLand advances through time
# The polymers of Eureka worked for 0.0035 polyears.
# The polymers of Eureka married!
# The nation of Eureka took 1.1261 years to finish their census!
# There are 174 polymers in the nation
# After 0.0417 years they had children.
# Generation 6 of Eureka have all passed away
# Age of planet Planet_Silly: 27
# The polymers of UnitedPolymersOfCool took 1.0773 years to mature.
# The polymers of UnitedPolymersOfCool took 0.047 years to graduate college.
# The polymers of UnitedPolymersOfCool worked for 0.0019 years.
# The polymers of UnitedPolymersOfCool emigrated over 0.6882 years.
# The polymers of Eureka took 0.9881 years to mature.
# The polymers of Eureka took 0.0594 years to graduate college.
# The polymers of Eureka worked for 0.0039 years.
# The polymers of Eureka emigrated over 0.6591 years.
# Age of land Awesomeland is 27
# UnitedPolymersOfCool of Awesomeland advances through time
# The polymers of UnitedPolymersOfCool worked for 0.0053 polyears.
# The polymers of UnitedPolymersOfCool married!
# The nation of UnitedPolymersOfCool took 0.8404 years to finish their census!
# There are 152 polymers in the nation
# After 0.041 years they had children.
# Generation 27 of UnitedPolymersOfCool have all passed away
# Age of land SmartLand is 7
# Eureka of SmartLand advances through time
# The polymers of Eureka worked for 0.0059 polyears.
# The polymers of Eureka married!
# The nation of Eureka took 1.0935 years to finish their census!
# There are 168 polymers in the nation
# After 0.0316 years they had children.
# Generation 7 of Eureka have all passed away
# Age of planet Planet_Silly: 28
# The polymers of UnitedPolymersOfCool took 0.948 years to mature.
# The polymers of UnitedPolymersOfCool took 0.0432 years to graduate college.
# The polymers of UnitedPolymersOfCool worked for 0.0035 years.
# The polymers of UnitedPolymersOfCool emigrated over 0.5583 years.
# The polymers of Eureka took 0.907 years to mature.
# The polymers of Eureka took 0.0422 years to graduate college.
# The polymers of Eureka worked for 0.0016 years.
# The polymers of Eureka emigrated over 0.7391 years.
# Age of land Awesomeland is 28
# UnitedPolymersOfCool of Awesomeland advances through time
# The polymers of UnitedPolymersOfCool worked for 0.0035 polyears.
# The polymers of UnitedPolymersOfCool married!
# The nation of UnitedPolymersOfCool took 0.822 years to finish their census!
# There are 152 polymers in the nation
# After 0.0314 years they had children.
# Generation 28 of UnitedPolymersOfCool have all passed away
# Age of land SmartLand is 8
# Eureka of SmartLand advances through time
# The polymers of Eureka worked for 0.0059 polyears.
# The polymers of Eureka married!
# The nation of Eureka took 1.1116 years to finish their census!
# There are 182 polymers in the nation
# After 0.0552 years they had children.
# Generation 8 of Eureka have all passed away
# Age of planet Planet_Silly: 29
# The polymers of UnitedPolymersOfCool took 0.9607 years to mature.
# The polymers of UnitedPolymersOfCool took 0.0418 years to graduate college.
# The polymers of UnitedPolymersOfCool worked for 0.002 years.
# The polymers of UnitedPolymersOfCool emigrated over 0.5668 years.
# The polymers of Eureka took 1.0211 years to mature.
# The polymers of Eureka took 0.0464 years to graduate college.
# The polymers of Eureka worked for 0.0013 years.
# The polymers of Eureka emigrated over 0.5634 years.
# Age of land Awesomeland is 29
# UnitedPolymersOfCool of Awesomeland advances through time
# The polymers of UnitedPolymersOfCool worked for 0.0032 polyears.
# The polymers of UnitedPolymersOfCool married!
# The nation of UnitedPolymersOfCool took 0.6591 years to finish their census!
# There are 144 polymers in the nation
# After 0.0329 years they had children.
# Generation 29 of UnitedPolymersOfCool have all passed away
# Age of land SmartLand is 9
# Eureka of SmartLand advances through time
# The polymers of Eureka worked for 0.0042 polyears.
# The polymers of Eureka married!
# The nation of Eureka took 0.7966 years to finish their census!
# There are 173 polymers in the nation
# After 0.0368 years they had children.
# Generation 9 of Eureka have all passed away

# %% [markdown]
# # A plateau
# Looks like we can increase intelligence a little more, but not enough to reach our goals.

# %%
df, fp_df = pga.load_planet('data/Planet_Silly')
plot_property_averages(df)

# %%
plot_average_lengths(df)

# %%
count_num_successful_pols(df)
# Out:
# Eureka: 0 / 1704
# UnitedPolymersOfCool: 0 / 4561

# %% [markdown]
# # Closing the run
# Don't roget to complete the run (close the sql connection)!

# %%
planet.complete_run()
# Out:
# Planet Planet_Silly passes into oblivion...

# %% [markdown]
# # Deleting the planet
# I throw an error if you try to overwrite your planet, so we'll delete these results in case we want to run the code again. In real life, you wouldn't want to do that.

# %%
rm -r data/Planet_Silly
